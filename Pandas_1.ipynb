# %% [markdown]
# ### Pandas引入约定

# %%
from pandas import Series,DataFrame

# %%
import pandas as pd

# %% [markdown]
# ## Series

# %%
import numpy as np

# %% [markdown]
# ### 通过一维数组创建Series

# %%
arr=np.array([1,2,3,4])

# %%
series01 = Series(arr)

# %%
series01
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int32

# %%
series01.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
series01.values
# Out:
# array([1, 2, 3, 4])

# %%
series01.dtype
# Out:
# dtype('int32')

# %%
series02=Series([34.5,56.78,45.67])

# %%
series02
# Out:
# 0    34.50
# 1    56.78
# 2    45.67
# dtype: float64

# %%
series02.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %% [markdown]
# ### 修改默认索引
#     通过数组创建时，如果没有指定索引，默认会创建一个从0到N-1（N为数据的长度）的整数型索引,可以通过赋值的方式进行修改

# %%
series02.index=['product1','product2','product3']

# %%
series02
# Out:
# product1    34.50
# product2    56.78
# product3    45.67
# dtype: float64

# %% [markdown]
#     通过数组创建Series时，可以通过index参数传入一个明确的标签索引

# %%
series03=Series([98,56,88,45],index=['语文','数学','英语','体育'])

# %%
series03
# Out:
# 语文    98
# 数学    56
# 英语    88
# 体育    45
# dtype: int64

# %%
series03.index
# Out:
# Index([u'语文', u'数学', u'英语', u'体育'], dtype='object')

# %%
series03.values
# Out:
# array([98, 56, 88, 45], dtype=int64)

# %% [markdown]
# ### 通过字典方式创建Series
#     Series可以被看做是一个定长的有序字典，是索引值到数据值的一个映射，可以直接通过字典来创建Series

# %%
a_dict={'201701':6798.98,'201702':34556.89,'201703':3748758.88}

# %%
series04= Series(a_dict)

# %%
series04
# Out:
# 201701       6798.98
# 201702      34556.89
# 201703    3748758.88
# dtype: float64

# %%
series04.index
# Out:
# Index([u'201701', u'201702', u'201703'], dtype='object')

# %% [markdown]
# ### Series应用NumPy数组运算

# %%
series04['201701']
# Out:
# 6798.9799999999996

# %%
series04[0]
# Out:
# 6798.9799999999996

# %%
series04[series04>10000]
# Out:
# 201702      34556.89
# 201703    3748758.88
# dtype: float64

# %%
series04>10000
# Out:
# 201701    False
# 201702     True
# 201703     True
# dtype: bool

# %%
series04/100
# Out:
# 201701       67.9898
# 201702      345.5689
# 201703    37487.5888
# dtype: float64

# %%
series01
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int32

# %%
np.exp([series01])
# Out:
# array([[  2.71828183,   7.3890561 ,  20.08553692,  54.59815003]])

# %% [markdown]
# ### Series缺失值检测
#      pandas中的isnull和notnull函数可用于缺失值检测,返回一个布尔类型的Series

# %%
scores = Series({"Tom":89,"John":88,"Merry":96,"Max":65})

# %%
scores
# Out:
# John     88
# Max      65
# Merry    96
# Tom      89
# dtype: int64

# %%
new_index=['Tom','Max','Joe',"John","Merry"]

# %%
scores.index=new_index
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-837a0db07e0b> in <module>()
# ----> 1 scores.index=new_index
#
# D:\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __setattr__(self, name, value)
#    2755         try:
#    2756             object.__getattribute__(self, name)
# -> 2757             return object.__setattr__(self, name, value)
#    2758         except AttributeError:
#    2759             pass
#
# pandas\src\properties.pyx in pandas.lib.AxisProperty.__set__ (pandas\lib.c:46249)()
#
# D:\Anaconda2\lib\site-packages\pandas\core\series.pyc in _set_axis(self, axis, labels, fastpath)
#     308         object.__setattr__(self, '_index', labels)
#     309         if not fastpath:
# --> 310             self._data.set_axis(axis, labels)
#     311
#     312     def _set_subtyp(self, is_all_dates):
#
# D:\Anaconda2\lib\site-packages\pandas\core\internals.pyc in set_axis(self, axis, new_labels)
#    2800             raise ValueError('Length mismatch: Expected axis has %d elements, '
#    2801                              'new values have %d elements' %
# -> 2802                              (old_len, new_len))
#    2803
#    2804         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 4 elements, new values have 5 elements

# %%
scores=Series(scores,index=new_index)

# %%
scores
# Out:
# Tom      89.0
# Max      65.0
# Joe       NaN
# John     88.0
# Merry    96.0
# dtype: float64

# %%
pd.isnull(scores)
# Out:
# Tom      False
# Max      False
# Joe       True
# John     False
# Merry    False
# dtype: bool

# %%
pd.notnull(scores)
# Out:
# Tom       True
# Max       True
# Joe      False
# John      True
# Merry     True
# dtype: bool

# %%
scores[pd.isnull(scores)]
# Out:
# Joe   NaN
# dtype: float64

# %%
scores[pd.notnull(scores)]
# Out:
# Tom      89.0
# Max      65.0
# John     88.0
# Merry    96.0
# dtype: float64

# %% [markdown]
# ### Series 自动对齐
#     不同Series之间进行运算，会自动对齐不同索引的数据

# %%
product_num = Series([23,45,67,89],index=['p3','p1','p2','p5'])

# %%
product_num
# Out:
# p3    23
# p1    45
# p2    67
# p5    89
# dtype: int64

# %%
product_price_table=Series([9.98,2.34,4.56,5.67,8.78],index=['p1','p2','p3','p4','p5'])

# %%
product_price_table
# Out:
# p1    9.98
# p2    2.34
# p3    4.56
# p4    5.67
# p5    8.78
# dtype: float64

# %%
product_sum=product_num*product_price_table

# %%
product_sum
# Out:
# p1    449.10
# p2    156.78
# p3    104.88
# p4       NaN
# p5    781.42
# dtype: float64

# %% [markdown]
# ### Series 及其索引的name属性
#     Series对象本身及其索引都有一个name属性，可赋值设置

# %%
product_num.name='ProductNums'

# %%
product_num.index.name='ProductType'

# %%
product_num
# Out:
# ProductType
# p3    23
# p1    45
# p2    67
# p5    89
# Name: ProductNums, dtype: int64

# %% [markdown]
# ### DataFrame

# %% [markdown]
# #### 通过二维数组创建DataFrame

# %%
df01=DataFrame([['Tom','Merry',"John"],[76,98,100]])

# %%
df01
# Out:
#      0      1     2
# 0  Tom  Merry  John
# 1   76     98   100

# %%
df02=DataFrame([['Tom',76],['Merry',98],['John',100]])

# %%
df02
# Out:
#        0    1
# 0    Tom   76
# 1  Merry   98
# 2   John  100

# %%
arr=np.array([['Tom',76],['Merry',98],['John',100]])

# %%
df03=DataFrame(arr,columns=['name','score'])

# %%
df03
# Out:
#     name score
# 0    Tom    76
# 1  Merry    98
# 2   John   100

# %%
df04=DataFrame(arr,index=['one','two','three'],columns=['name','score'])

# %%
df04
# Out:
#         name score
# one      Tom    76
# two    Merry    98
# three   John   100

# %% [markdown]
# #### 通过字典方式创建DataFrame

# %%
data={'apart':['1001','1002','1003','1001'],
     'profits':[567.87,987.87,873,498.87],
     'year':[2001,2001,2001,2000]}

# %%
df=DataFrame(data)

# %%
df
# Out:
#   apart  profits  year
# 0  1001   567.87  2001
# 1  1002   987.87  2001
# 2  1003   873.00  2001
# 3  1001   498.87  2000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.columns
# Out:
# Index([u'apart', u'profits', u'year'], dtype='object')

# %%
df.values
# Out:
# array([['1001', 567.87, 2001L],
#        ['1002', 987.87, 2001L],
#        ['1003', 873.0, 2001L],
#        ['1001', 498.87, 2000L]], dtype=object)

# %%
df=DataFrame(data,index=['one','two','three','four'])

# %%
df
# Out:
#       apart  profits  year
# one    1001   567.87  2001
# two    1002   987.87  2001
# three  1003   873.00  2001
# four   1001   498.87  2000

# %%
df.index
# Out:
# Index([u'one', u'two', u'three', u'four'], dtype='object')
